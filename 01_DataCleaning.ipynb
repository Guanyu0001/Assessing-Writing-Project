# %%
# Step 1: Imports
import pandas as pd
import numpy as np

# Step 2: Load CSV
df = pd.read_csv("persuade_2.0_human_scores_demo_id_github.csv")

# Step 3: Quick overview
print(df.shape)
print(df.columns)
df.head()
