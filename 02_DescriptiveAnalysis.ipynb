# %%
# ======================================================
# Code 02 — Basic Descriptive Analysis (Persuade 2.0)
# ======================================================
# Purpose:
#   Load the cleaned dataset and produce simple descriptive
#   summaries to set up later analyses.
#
# Input:
#   ./data/persuade_clean.csv (from Code 01)
# ======================================================

import pandas as pd
from IPython.display import display

# -------------------------------
# 1) Load Data
# -------------------------------
df = pd.read_csv("./data/persuade_clean.csv")

# -------------------------------
# 2) Dataset Overview
# -------------------------------
print("=== Dataset Info ===")
df.info()

print("\n=== Dataset Describe ===")
# use display() for better rendering in Jupyter
display(df.describe(include="all"))

# -------------------------------
# 3) Gender Distribution
# -------------------------------
print("\n=== Gender Distribution ===")
if "gender" in df.columns:
    counts = df["gender"].value_counts(dropna=False).rename("count")
    perc = df["gender"].value_counts(normalize=True, dropna=False).mul(100).round(2).rename("percent")
    gender_table = pd.concat([counts, perc], axis=1)
    display(gender_table)
else:
    print("Column 'gender' not found.")

# -------------------------------
# 4) Holistic Essay Score (3-category) Distribution
# -------------------------------
print("\n=== Holistic Essay Score (1–3) Distribution ===")
if "holistic_essay_score_3cat" in df.columns:
    score_counts = df["holistic_essay_score_3cat"].value_counts().sort_index().rename("count")
    score_perc = df["holistic_essay_score_3cat"].value_counts(normalize=True).sort_index().mul(100).round(2).rename("percent")
    score_table = pd.concat([score_counts, score_perc], axis=1)
    display(score_table)
else:
    print("Column 'holistic_essay_score_3cat' not found.")

# -------------------------------
# 5) Basic Text Length Statistics
# -------------------------------
print("\n=== Text Length Statistics (from full_text) ===")
if "full_text" in df.columns:
    full_text = df["full_text"].fillna("").astype(str)
    char_count = full_text.str.len()
    word_count = full_text.str.split().str.len()

    summary = pd.DataFrame({
        "char_count": char_count.describe().round(2),
        "word_count": word_count.describe().round(2)
    })
    display(summary)
else:
    print("Column 'full_text' not found.")
# Out:
# === Dataset Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2167 entries, 0 to 2166
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   essay_id_comp              2167 non-null   object
#  1   full_text                  2167 non-null   object
#  2   gender                     2167 non-null   object
#  3   holistic_essay_score       2167 non-null   int64
#  4   holistic_essay_score_3cat  2167 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 84.8+ KB
#
# === Dataset Describe ===
#        essay_id_comp                                          full_text  \
# count           2167                                               2167
# unique          2167                                               2167
# top     4B4C70FDFC25  Using a Facial action cosing system can be ver...
# freq               1                                                  1
# mean             NaN                                                NaN
# std              NaN                                                NaN
# min              NaN                                                NaN
# 25%              NaN                                                NaN
# 50%              NaN                                                NaN
# 75%              NaN                                                NaN
# max              NaN                                                NaN
#
#        gender  holistic_essay_score  holistic_essay_score_3cat
# count    2167           2167.000000                2167.000000
# unique      2                   NaN                        NaN
# top         M                   NaN                        NaN
# freq     1140                   NaN                        NaN
# mean      NaN              2.875865                   1.693124
# std       NaN              1.111430                   0.621605
# min       NaN              1.000000                   1.000000
# 25%       NaN              2.000000                   1.000000
# 50%       NaN              3.000000                   2.000000
# 75%       NaN              3.000000                   2.000000
# max       NaN              6.000000                   3.000000
# === Gender Distribution ===
#         count  percent
# gender
# M        1140    52.61
# F        1027    47.39
# === Holistic Essay Score (1–3) Distribution ===
#                            count  percent
# holistic_essay_score_3cat
# 1                            853    39.36
# 2                           1126    51.96
# 3                            188     8.68
# === Text Length Statistics (from full_text) ===
#        char_count  word_count
# count     2167.00     2167.00
# mean      1951.24      343.36
# std        893.82      147.41
# min        737.00      151.00
# 25%       1285.50      230.00
# 50%       1758.00      313.00
# 75%       2369.00      419.00
# max       9457.00     1235.00
